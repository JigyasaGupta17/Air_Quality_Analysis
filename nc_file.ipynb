# %%
pip install netCDF4 xarray
# Out:
# ...
#                                               0.0/6.6 MB ? eta -:--:--
#                                               0.1/6.6 MB 4.3 MB/s eta 0:00:02
#      --                                       0.4/6.6 MB 6.5 MB/s eta 0:00:01
#      ----                                     0.7/6.6 MB 6.2 MB/s eta 0:00:01
#      ------                                   1.0/6.6 MB 6.4 MB/s eta 0:00:01
#      -------                                  1.2/6.6 MB 6.2 MB/s eta 0:00:01
#      --------                                 1.4/6.6 MB 5.7 MB/s eta 0:00:01
#      --------                                 1.5/6.6 MB 5.3 MB/s eta 0:00:01
#      ----------                               1.7/6.6 MB 5.3 MB/s eta 0:00:01
#      ----------                               1.8/6.6 MB 5.0 MB/s eta 0:00:01
#      ------------                             2.0/6.6 MB 4.9 MB/s eta 0:00:01
#      ------------                             2.2/6.6 MB 4.9 MB/s eta 0:00:01
# ...

# %%
import netCDF4
df1 = netCDF4.Dataset("E:\dddd\CERES_EBAF-TOA_Ed4.2_Subset_201503-202310.nc")

# %%
veiw = df1.variables
print(veiw)
# Out:
# {'lon': <class 'netCDF4._netCDF4.Variable'>
# float32 lon(lon)
#     long_name: Longitude
#     standard_name: longitude
#     units: degrees_east
#     valid_range: [-180.  360.]
# unlimited dimensions:
# current shape = (33,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'lat': <class 'netCDF4._netCDF4.Variable'>
# float32 lat(lat)
#     long_name: Latitude
#     standard_name: latitude
#     units: degrees_north
#     valid_range: [-90.  90.]
# unlimited dimensions:
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'time': <class 'netCDF4._netCDF4.Variable'>
# int32 time(time)
#     long_name: Time
#     units: days since 2000-03-01 00:00:00
#     delta_t: 0000-00-01 00:00:00
# unlimited dimensions:
# current shape = (104,)
# filling on, default _FillValue of -2147483647 used, 'toa_sw_all_mon': <class 'netCDF4._netCDF4.Variable'>
# float32 toa_sw_all_mon(time, lat, lon)
# ...

# %%
print(df1.dimensions)
print(df1.variables['lon'].ncattrs())
# Out:
# {'lon': <class 'netCDF4._netCDF4.Dimension'>: name = 'lon', size = 33, 'lat': <class 'netCDF4._netCDF4.Dimension'>: name = 'lat', size = 32, 'time': <class 'netCDF4._netCDF4.Dimension'>: name = 'time', size = 104}
# ['long_name', 'standard_name', 'units', 'valid_range']

# %%
df2 = netCDF4.Dataset("E:\dddd\g4.areaAvgTimeSeries.MOD08_D3_6_1_Aerosol_Optical_Depth_Land_Ocean_Mean.20150101-20221231.67E_3N_90E_36N.nc")

# %%
print(df2.variables)
# Out:
# {'MOD08_D3_6_1_Aerosol_Optical_Depth_Land_Ocean_Mean': <class 'netCDF4._netCDF4.Variable'>
# float64 MOD08_D3_6_1_Aerosol_Optical_Depth_Land_Ocean_Mean(time)
#     _FillValue: -9999.0
#     Aggregation_Data_Set: None
#     Derived_From_Level_2_Data_Set: Optical_Depth_Land_And_Ocean
#     Included_Level_2_Nighttime_Data: False
#     Level_2_Pixel_Values_Read_As: Real
#     Quality_Assurance_Data_Set: None
#     Statistic_Type: Simple
#     long_name: Aerosol Optical Depth 550 nm (Dark Target)
#     product_short_name: MOD08_D3
#     product_version: 6.1
#     quantity_type: Aerosol Optical Depth
#     standard_name: Aerosol Optical Depth
#     units: 1
#     valid_max: 5.0
#     valid_min: -0.1
#     cell_methods: time: mean lat, lon: mean
#     coordinates: time
# unlimited dimensions: time
# current shape = (2901,)
# filling on, 'dataday': <class 'netCDF4._netCDF4.Variable'>
# int32 dataday(time)
#     long_name: Standardized Date Label
#     cell_methods: time: mean
# ...
